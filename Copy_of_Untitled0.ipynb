# %% [markdown]
# <a href="https://colab.research.google.com/github/marounna/cloud/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Provide the path to your text file on Google Drive
file_path = '/content/drive/MyDrive/Colab_Notebooks/Students.txt'

# Read the content of the file into a pandas DataFrame
data = pd.read_csv(file_path, header=None, names=['Name', 'Email', 'Courses','Link'])
# Display the loaded data
data
# Out:
#             Name                           Email  \
# 0  'Abed Tayar '   'Abed.tayar@e.braude.ac.il'
#
#                                              Courses            Link
# 0   'data compression Introduction to cloud compu...    'google.com'

# %%
import ipywidgets as widgets
import pandas as pd

file_path = '/content/drive/MyDrive/Colab_Notebooks/Students.txt'

# Read the content of the file into a pandas DataFrame
data = pd.read_csv(file_path, header=None, names=['Name', 'Email', 'Courses', 'Link'])

# Create a dropdown menu for student names
name_dropdown = widgets.Dropdown(
    options=data['Name'].tolist(),
    description='Select Student:',
    style={'description_width': 'initial'}
)

# Create text areas for displaying information
info_name = widgets.Text(
    value='',
    description='Name:',
    disabled=True,
    style={'description_width': 'initial'}
)

info_email = widgets.Text(
    value='',
    description='Email:',
    disabled=True,
    style={'description_width': 'initial'}
)

info_courses = widgets.Textarea(
    value='',
    description='Courses:',
    disabled=True,
    style={'description_width': 'initial'}
)

info_link = widgets.Text(
    value='',
    description='Link:',
    disabled=True,
    style={'description_width': 'initial'}
)

# Create a text input for the favorite show
favorite_show_input = widgets.Text(
    value='',
    description='Favorite Show:',
    style={'description_width': 'initial'}
)

# Create a button for updating the data
update_button = widgets.Button(description='Update Show')

# Function to append the new favorite show to the file
def append_show(button):
    with open(file_path, 'a') as file:
        file.write(f"\n{name_dropdown.value}, {favorite_show_input.value}")

# Assign the button event
update_button.on_click(append_show)

# Function to update information when a student is selected
def update_info(change):
    selected_name = change['new']
    student_info = data[data['Name'] == selected_name].squeeze()

    # Update the widgets with the student's information
    info_name.value = student_info['Name']
    info_email.value = student_info['Email']
    info_courses.value = student_info['Courses']
    info_link.value = student_info['Link']

# Assign the function to the dropdown's observe event
name_dropdown.observe(update_info, names='value')

# Display the widgets
widgets.VBox([name_dropdown, info_name, info_email, info_courses, info_link, favorite_show_input, update_button])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-16a59baa16b2> in <cell line: 7>()
#       5
#       6 # Read the content of the file into a pandas DataFrame
# ----> 7 data = pd.read_csv(file_path, header=None, names=['Name', 'Email', 'Courses', 'Link'])
#       8
#       9 # Create a dropdown menu for student names
#
# ...
